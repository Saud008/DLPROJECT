# %% [markdown]
# # **Mounting From Google drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Importing Required Libraries

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.nn import functional as F
from torch.nn.parameter import Parameter
import torch.optim as optim

from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms, utils, datasets
import matplotlib.pyplot as plt


torch.set_printoptions(linewidth=120)
torch.set_grad_enabled(True)

# %% [markdown]
# ## Network

# %%
class Network(nn.Module):
    def __init__(self):
        super().__init__()

        self.features = nn.Sequential(
            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(3, 32, kernel_size=5, stride=2),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.Dropout(p = 0.1),

            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(32, 64, kernel_size=5, stride=2),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Dropout(p = 0.2),

            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(64, 128, kernel_size=5),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.Dropout(p = 0.2),

            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(128,256, kernel_size=3),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
        )

        self.classifier = nn.Sequential(
            nn.Dropout(p = 0.2),
            nn.Linear(16384, 256),
            # nn.BatchNorm1d(256),
            nn.ReLU(inplace=True),

            nn.Dropout(p = 0.2),
            nn.Linear(256, 128),
            # nn.BatchNorm1d(128),
            nn.ReLU(inplace=True),

            nn.Dropout(p = 0.1),
            nn.Linear(128, 6),
#             nn.BatchNorm1d(512), not in this model
            nn.Softmax(dim=1)
        )



    def forward(self, x):
        x = self.features(x)
        x = x.reshape(-1, 16384)
        x = self.classifier(x)

        return x

def get_num_correct(pred, label):
    return pred.argmax(dim=1).eq(label).sum().item()

# %% [markdown]
# ## Moving To GPU

# %%
device = torch.device("cuda:0")
print(device)
if torch.cuda.is_available():
    device = torch.device("cuda:0")  # you can continue going on here, like cuda:1 cuda:2....etc.
    print("Running on the GPU")
else:
    device = torch.device("cpu")
    print("Running on the CPU")
# Out:
# cuda:0
# Running on the GPU

# %% [markdown]
# # **Test the Model**

# %% [markdown]
# ## Test Dataset Creation

# %%
mean = 0.2069
std = 0.1471

# %%
test_data_dir = '/content/drive/MyDrive/dataset/a15083/test'

transform_test = transforms.Compose([
     transforms.CenterCrop((800,800)),
     transforms.ToTensor(),
     ])

test_dataset = datasets.ImageFolder(root =test_data_dir,transform = transform_test)
test_dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 6588
#     Root location: /content/drive/MyDrive/dataset/a15083/test
#     StandardTransform
# Transform: Compose(
#                CenterCrop(size=(800, 800))
#                ToTensor()
#            )

# %% [markdown]
# ## Generating true labels

# %%
import json
# Opening JSON file
f = open('/content/drive/MyDrive/dataset/a15083/test/test.json',)

label_test = json.load(f)

# %%
keys_orig = list(label_test.keys())
values = list(label_test.values())
keys = []
for key in keys_orig:
  a_string = key
  a_string = a_string.replace("/", " ")
  x = a_string.split()
  string = x[0]+' '+x[1]
  keys.append(string)
true_test_labels_dict = {keys[i]: values[i] for i in range(len(keys))}
true_test_labels_dict
# Out:
# {'170906-143512-Al 2mm-part2': 1,
#  '170904-155610-Al 2mm': 2,
#  '170906-143512-Al 2mm-part1': 2,
#  '170904-154202-Al 2mm-part1': 2,
#  '170904-150144-Al 2mm-part2': 4,
#  '170906-155007-Al 2mm-part2': 4,
#  '170913-154448-Al 2mm': 0,
#  '170906-113317-Al 2mm-part1': 0,
#  '170905-112213-Al 2mm': 0,
#  '170906-104925-Al 2mm': 0,
#  '170904-152301-Al 2mm-part2': 5,
#  '170906-153326-Al 2mm-part3': 3,
#  '170906-151724-Al 2mm-part1': 3,
#  '170906-155007-Al 2mm-part1': 3}

# %% [markdown]
# ### 2 Class Test

# %%
true_test_labels_dict2 = {}
for key,value in true_test_labels_dict.items():
  if value ==0:
    val = 0
  else:
    val = 1
  dict2 = {key:val}
  true_test_labels_dict2.update(dict2)
true_test_labels_dict2
# Out:
# {'170906-143512-Al 2mm-part2': 1,
#  '170904-155610-Al 2mm': 1,
#  '170906-143512-Al 2mm-part1': 1,
#  '170904-154202-Al 2mm-part1': 1,
#  '170904-150144-Al 2mm-part2': 1,
#  '170906-155007-Al 2mm-part2': 1,
#  '170913-154448-Al 2mm': 0,
#  '170906-113317-Al 2mm-part1': 0,
#  '170905-112213-Al 2mm': 0,
#  '170906-104925-Al 2mm': 0,
#  '170904-152301-Al 2mm-part2': 1,
#  '170906-153326-Al 2mm-part3': 1,
#  '170906-151724-Al 2mm-part1': 1,
#  '170906-155007-Al 2mm-part1': 1}

# %% [markdown]
# ## Matching the loaded data with Labels

# %%
original_test_labels_dict = test_dataset.class_to_idx
original_test_labels_dict
# Out:
# {'170904-150144-Al 2mm-part2': 0,
#  '170904-152301-Al 2mm-part2': 1,
#  '170904-154202-Al 2mm-part1': 2,
#  '170904-155610-Al 2mm': 3,
#  '170905-112213-Al 2mm': 4,
#  '170906-104925-Al 2mm': 5,
#  '170906-113317-Al 2mm-part1': 6,
#  '170906-143512-Al 2mm-part1': 7,
#  '170906-143512-Al 2mm-part2': 8,
#  '170906-151724-Al 2mm-part1': 9,
#  '170906-153326-Al 2mm-part3': 10,
#  '170906-155007-Al 2mm-part1': 11,
#  '170906-155007-Al 2mm-part2': 12,
#  '170913-154448-Al 2mm': 13}

# %% [markdown]
# ### 2 Class test

# %%
original_test_labels_dict2 = {}
for key,value in original_test_labels_dict.items():
  if value ==0:
    val = 0
  else:
    val = 1
  dict2 = {key:val}
  original_test_labels_dict2.update(dict2)
original_test_labels_dict2
# Out:
# {'170904-150144-Al 2mm-part2': 0,
#  '170904-152301-Al 2mm-part2': 1,
#  '170904-154202-Al 2mm-part1': 1,
#  '170904-155610-Al 2mm': 1,
#  '170905-112213-Al 2mm': 1,
#  '170906-104925-Al 2mm': 1,
#  '170906-113317-Al 2mm-part1': 1,
#  '170906-143512-Al 2mm-part1': 1,
#  '170906-143512-Al 2mm-part2': 1,
#  '170906-151724-Al 2mm-part1': 1,
#  '170906-153326-Al 2mm-part3': 1,
#  '170906-155007-Al 2mm-part1': 1,
#  '170906-155007-Al 2mm-part2': 1,
#  '170913-154448-Al 2mm': 1}

# %% [markdown]
# ## Label Mapping

# %%
test_label_map_dict = {}

for key,value in original_test_labels_dict.items():
  test_label_map_dict.update({value:true_test_labels_dict[key]})
test_label_map_dict
# Out:
# {0: 4,
#  1: 5,
#  2: 2,
#  3: 2,
#  4: 0,
#  5: 0,
#  6: 0,
#  7: 2,
#  8: 1,
#  9: 3,
#  10: 3,
#  11: 3,
#  12: 4,
#  13: 0}

# %% [markdown]
# ### 2 Class test

# %%
test_label_map_dict2 = {}

for key,value in original_test_labels_dict.items():
  test_label_map_dict2.update({value:true_test_labels_dict2[key]})
test_label_map_dict2
# Out:
# {0: 1,
#  1: 1,
#  2: 1,
#  3: 1,
#  4: 0,
#  5: 0,
#  6: 0,
#  7: 1,
#  8: 1,
#  9: 1,
#  10: 1,
#  11: 1,
#  12: 1,
#  13: 0}

# %% [markdown]
# ## Loading The Model

# %%
PATH_model = "/content/drive/MyDrive/modelv5.pt"

# %%
torch.save(net.state_dict(), PATH_model)

# %%
net = Network()
net.load_state_dict(torch.load(PATH_model, map_location=device))
net.to(device)
# Out:
# <ipython-input-21-0e6b95cebec0>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   net.load_state_dict(torch.load(PATH_model, map_location=device))
# Network(
#   (features): Sequential(
#     (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (1): Conv2d(3, 32, kernel_size=(5, 5), stride=(2, 2))
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#     (4): Dropout(p=0.1, inplace=False)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(32, 64, kernel_size=(5, 5), stride=(2, 2))
#     (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU(inplace=True)
#     (9): Dropout(p=0.2, inplace=False)
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1))
#     (12): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): ReLU(inplace=True)
#     (14): Dropout(p=0.2, inplace=False)
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (16): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1))
#     (17): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (18): ReLU(inplace=True)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=16384, out_features=256, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.2, inplace=False)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Dropout(p=0.1, inplace=False)
#     (7): Linear(in_features=128, out_features=6, bias=True)
#     (8): Softmax(dim=1)
#   )
# )

# %%
torch.cuda.empty_cache()
torch.set_grad_enabled(False)

# %% [markdown]
# ## Testing

# %% [markdown]
# ## Testing Overall Dataset

# %% [markdown]
# ### 6 Class Test

# %%
test_loader = DataLoader(test_dataset, batch_size=300, shuffle=True)

# %%
total_correct=0
correct_predictions = []
i=0
total = 0
for batch in test_loader:
  image, label_original = batch
  label = [test_label_map_dict[lab.item()] for lab in label_original]
  label = torch.tensor(label)


  pred = net(image.to(device))

  total_correct += get_num_correct(pred,label.to(device))
  correct_predictions.append(total_correct)

  total += len(label)
  acc = 100*total_correct/(total)
  print('Batch No: ',i+1,'/',len(test_loader),', Accuracy till Now : ', acc)
  i=i+1
print(total_correct/len(test_dataset))
# Out:
# Batch No:  1 / 22 , Accuracy till Now :  8.0
# Batch No:  2 / 22 , Accuracy till Now :  6.833333333333333
# Batch No:  3 / 22 , Accuracy till Now :  6.666666666666667
# Batch No:  4 / 22 , Accuracy till Now :  6.666666666666667
# Batch No:  5 / 22 , Accuracy till Now :  6.466666666666667
# Batch No:  6 / 22 , Accuracy till Now :  6.277777777777778
# Batch No:  7 / 22 , Accuracy till Now :  6.285714285714286
# Batch No:  8 / 22 , Accuracy till Now :  6.416666666666667
# Batch No:  9 / 22 , Accuracy till Now :  6.481481481481482
# Batch No:  10 / 22 , Accuracy till Now :  6.466666666666667
# Batch No:  11 / 22 , Accuracy till Now :  6.606060606060606
# Batch No:  12 / 22 , Accuracy till Now :  6.944444444444445
# Batch No:  13 / 22 , Accuracy till Now :  7.076923076923077
# Batch No:  14 / 22 , Accuracy till Now :  7.166666666666667
# Batch No:  15 / 22 , Accuracy till Now :  7.355555555555555
# Batch No:  16 / 22 , Accuracy till Now :  7.333333333333333
# Batch No:  17 / 22 , Accuracy till Now :  7.313725490196078
# Batch No:  18 / 22 , Accuracy till Now :  7.203703703703703
# Batch No:  19 / 22 , Accuracy till Now :  7.315789473684211
# Batch No:  20 / 22 , Accuracy till Now :  7.35
# Batch No:  21 / 22 , Accuracy till Now :  7.285714285714286
# Batch No:  22 / 22 , Accuracy till Now :  7.346690953248331
# 0.0734669095324833

# %% [markdown]
# ### 2 Class Test

# %%
def get_num_correct2(pred,true):
  prediction = pred.argmax(dim=1)
  label = []
  for val in prediction:
    if val.item() ==0:
      label.append(0)
    else:
      label.append(1)

  n = len(true)
  correct = 0
  for x in range(n):
      if true[x] == label[x]:
          correct += 1
  return correct

# %%
total_correct=0
correct_predictions = []
i=0
total = 0
for batch in test_loader:
  image, label_original = batch
  label = [test_label_map_dict2[lab.item()] for lab in label_original]
  label = torch.tensor(label)


  pred = net(image.to(device))

  total_correct += get_num_correct2(pred,label.to(device))
  correct_predictions.append(total_correct)

  total += len(label)
  acc = 100*total_correct/(total)
  print('Batch No: ',i+1,'/',len(test_loader),', Accuracy till Now : ', acc)
  i=i+1
print(total_correct/len(test_dataset))
# Out:
# Batch No:  1 / 22 , Accuracy till Now :  68.33333333333333
# Batch No:  2 / 22 , Accuracy till Now :  71.16666666666667
# Batch No:  3 / 22 , Accuracy till Now :  70.88888888888889
# Batch No:  4 / 22 , Accuracy till Now :  70.66666666666667
# Batch No:  5 / 22 , Accuracy till Now :  69.33333333333333
# Batch No:  6 / 22 , Accuracy till Now :  68.72222222222223
# Batch No:  7 / 22 , Accuracy till Now :  68.71428571428571
# Batch No:  8 / 22 , Accuracy till Now :  68.25
# Batch No:  9 / 22 , Accuracy till Now :  67.92592592592592
# Batch No:  10 / 22 , Accuracy till Now :  67.83333333333333
# Batch No:  11 / 22 , Accuracy till Now :  67.72727272727273
# Batch No:  12 / 22 , Accuracy till Now :  67.38888888888889
# Batch No:  13 / 22 , Accuracy till Now :  66.92307692307692
# Batch No:  14 / 22 , Accuracy till Now :  66.83333333333333
# Batch No:  15 / 22 , Accuracy till Now :  66.8
# Batch No:  16 / 22 , Accuracy till Now :  66.72916666666667
# Batch No:  17 / 22 , Accuracy till Now :  66.66666666666667
# Batch No:  18 / 22 , Accuracy till Now :  66.85185185185185
# Batch No:  19 / 22 , Accuracy till Now :  67.08771929824562
# Batch No:  20 / 22 , Accuracy till Now :  67.05
# Batch No:  21 / 22 , Accuracy till Now :  66.74603174603175
# Batch No:  22 / 22 , Accuracy till Now :  66.75774134790528
# 0.6675774134790529

# %% [markdown]
# ## Testing Over Specific Images

# %% [markdown]
# ### 6 Class Test

# %%
test_loader1 = DataLoader(test_dataset, batch_size=10,shuffle=True)

# %%
total_correct=0
condition = True
for batch in test_loader1:
  if condition:
    image, label_original = batch
    label = [test_label_map_dict[lab.item()] for lab in label_original]
    label = torch.tensor(label)


    pred = net(image.to(device))

    total_correct += get_num_correct(pred,label.to(device))

    condition = False
  else:
    break
label_6class = label
pred_6class = pred.argmax(dim=1)

# %% [markdown]
# ### 2 Class Test

# %%
# test_loader1 = DataLoader(test_dataset, batch_size=30,shuffle=True)

# %%
def get_num_correct2(pred,true):
  prediction = pred.argmax(dim=1)
  label = []
  for val in prediction:
    if val.item() ==0:
      label.append(0)
    else:
      label.append(1)

  n = len(true)
  correct = 0
  for x in range(n):
      if true[x] == label[x]:
          correct += 1
  return correct

# %%
total_correct=0
condition = True
for batch in test_loader1:
  if condition:
    image, label_original = batch
    label = [test_label_map_dict2[lab.item()] for lab in label_original]
    label = torch.tensor(label)


    pred = net(image.to(device))

    total_correct += get_num_correct2(pred,label.to(device))

    condition = False
  else:
    break
label_2class = label
pred_2class = pred.argmax(dim=1)

# %% [markdown]
# ## Defect Correspoing the label

# %%
weld_type = {
    0: 'Good Weld',
    1: 'Defective Weld',
    2: 'Defective Weld',
    3: 'Defective Weld',
    4:'Defective Weld',
    5:'Defective Weld'
}

# %% [markdown]
# ### 6 class

# %%
defect_label = {
    0: 'Good Weld',
    1: ' Burn through',
    2: 'Contamination',
    3: 'Lack of fusion',
    4:'Misalignment',
    5:'Lack of penetration'
}

# %% [markdown]
# ### 2 Class

# %%
defect_label2 = {
    0: 'Good Weld',
    1: 'Defective Weld'
}

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## 6 Class

# %%
for i in range(len(pred_6class)):
  print('=> Image No :',i+1)
  img= image[i]
  print(' Type of Weld :', weld_type[label_6class[i].item()])
  print(' Actual Defect :', defect_label[label_6class[i].item()])
  print(' Predicted Defect : ',defect_label[pred_6class[i].item()])
  plt.imshow(  img.permute(1, 2, 0)  )
  plt.show()
  print('-------------------xxxx--------------------------')
# Out:
# => Image No : 1
#  Type of Weld : Defective Weld
#  Actual Defect : Contamination
#  Predicted Defect :   Burn through
# -------------------xxxx--------------------------
# => Image No : 2
#  Type of Weld : Defective Weld
#  Actual Defect : Misalignment
#  Predicted Defect :   Burn through
# -------------------xxxx--------------------------
# => Image No : 3
#  Type of Weld : Defective Weld
#  Actual Defect : Contamination
#  Predicted Defect :   Burn through
# -------------------xxxx--------------------------
# => Image No : 4
#  Type of Weld : Defective Weld
#  Actual Defect : Contamination
#  Predicted Defect :   Burn through
# -------------------xxxx--------------------------
# => Image No : 5
#  Type of Weld : Good Weld
#  Actual Defect : Good Weld
#  Predicted Defect :   Burn through
# -------------------xxxx--------------------------
# => Image No : 6
#  Type of Weld : Defective Weld
#  Actual Defect : Contamination
#  Predicted Defect :   Burn through
# -------------------xxxx--------------------------
# => Image No : 7
#  Type of Weld : Good Weld
#  Actual Defect : Good Weld
#  Predicted Defect :   Burn through
# -------------------xxxx--------------------------
# => Image No : 8
#  Type of Weld : Good Weld
#  Actual Defect : Good Weld
#  Predicted Defect :   Burn through
# -------------------xxxx--------------------------
# => Image No : 9
#  Type of Weld : Good Weld
#  Actual Defect : Good Weld
#  Predicted Defect :  Lack of fusion
# -------------------xxxx--------------------------
# => Image No : 10
#  Type of Weld : Defective Weld
#  Actual Defect : Lack of fusion
#  Predicted Defect :   Burn through
# -------------------xxxx--------------------------
